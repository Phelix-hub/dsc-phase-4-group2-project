# %% [markdown]
#  ## Top Zip Codes for Investment Properties

# %% [markdown]
# ## Business Understanding

# %% [markdown]
# ### Project Overview

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# ### Objectives
#
# 1. To use Time Series Model to determine the top 5 zip codes to invest in
# 2. To find the top 5 zip codes nationwide with the highest ROI within accepted standard deviation threshold (variability in returns)
# 3. To Perform Forecasting for Future House Prices
# 4. Develop time series models to forecast real estate prices for different zip codes over various time horizons.
# 5. Evaluate the stability and predictability of real estate prices for different zip codes.
# 6. Determine potential profit margins based on historical data and forecasted price growth.
# 7. To Combine insights from the above analyses to make a comprehensive recommendation.
# 8. To effectively identify cities that are optimal for both short-term and long-term investment
# 9. To create user-friendly interfaces to facilitate easy access to forecast/ predictions and insights.

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# In this section, we will do the following to get more insights about our dataset before proceeding to subsequent steps.
# 1. Import the Libraries
# 2. Load and Explore the Time Series Data
# 3. Inspect the Data Types
# 4. Inspect the column values

# %%
#Importing the libraries to use
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import folium
import matplotlib.dates as mdates
import math
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

# %%
#Loading dataset into pandas DataFrame
df = pd.read_csv('zillow_data.csv')

# %%
#preview top 5 rows
df.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 0         1  334200.0  335400.0  336500.0  ...  1005500  1007500  1007800
# 1         2  235700.0  236900.0  236700.0  ...   308000   310000   312500
# 2         3  210400.0  212200.0  212200.0  ...   321000   320600   320200
# 3         4  498100.0  500900.0  503100.0  ...  1289800  1287700  1287400
# 4         5   77300.0   77300.0   77300.0  ...   119100   119400   120000
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0  1009600  1013300  1018700  1024400  1030700  1033800  1030600
# 1   314100   315000   316600   318100   319600   321100   321800
# 2   320400   320800   321200   321200   323000   326900   329900
# 3  1291500  1296600  1299000  1302700  1306400  1308500  1307000
# 4   120300   120300   120300   120300   120500   121000   121500
#
# [5 rows x 272 columns]

# %%
#preview last 5 rows
df.tail()
# Out:
#        RegionID  RegionName                 City State            Metro  \
# 14718     58333        1338             Ashfield    MA  Greenfield Town
# 14719     59107        3293            Woodstock    NH        Claremont
# 14720     75672       40404                Berea    KY         Richmond
# 14721     93733       81225  Mount Crested Butte    CO              NaN
# 14722     95851       89155             Mesquite    NV        Las Vegas
#
#       CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2017-07  \
# 14718   Franklin     14719   94600.0   94300.0   94000.0  ...   216800
# 14719    Grafton     14720   92700.0   92500.0   92400.0  ...   202100
# 14720    Madison     14721   57100.0   57300.0   57500.0  ...   121800
# 14721   Gunnison     14722  191100.0  192400.0  193700.0  ...   662800
# 14722      Clark     14723  176400.0  176300.0  176100.0  ...   333800
#
#        2017-08  2017-09  2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  \
# 14718   217700   218600   218500   218100   216400   213100   209800   209200
# 14719   208400   212200   215200   214300   213100   213700   218300   222700
# 14720   122800   124600   126700   128800   130600   131700   132500   133000
# 14721   671200   682400   695600   695500   694700   706400   705300   681500
# 14722   336400   339700   343800   346800   348900   350400   353000   356000
#
#        2018-04
# 14718   209300
# 14719   225800
# 14720   133400
# 14721   664400
# 14722   357200
#
# [5 rows x 272 columns]

# %%
#check shape of the df
df.shape
# Out:
# (14723, 272)

# %%
#check general df info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14723 entries, 0 to 14722
# Columns: 272 entries, RegionID to 2018-04
# dtypes: float64(219), int64(49), object(4)
# memory usage: 30.6+ MB

# %%
df.dtypes
# Out:
# RegionID       int64
# RegionName     int64
# City          object
# State         object
# Metro         object
#                ...
# 2017-12        int64
# 2018-01        int64
# 2018-02        int64
# 2018-03        int64
# 2018-04        int64
# Length: 272, dtype: object

# %% [markdown]
# ### Step 2: Data Preprocessing

# %%
def get_datetimes(df):
    """
    Takes a dataframe:
    returns only those column names that can be converted into datetime objects 
    as datetime objects.
    NOTE number of returned columns may not match total number of columns in passed dataframe
    """
    
    return pd.to_datetime(df.columns.values[7:], format='%Y-%m')

# %%
get_datetimes(df)
# Out:
# DatetimeIndex(['1996-04-01', '1996-05-01', '1996-06-01', '1996-07-01',
#                '1996-08-01', '1996-09-01', '1996-10-01', '1996-11-01',
#                '1996-12-01', '1997-01-01',
#                ...
#                '2017-07-01', '2017-08-01', '2017-09-01', '2017-10-01',
#                '2017-11-01', '2017-12-01', '2018-01-01', '2018-02-01',
#                '2018-03-01', '2018-04-01'],
#               dtype='datetime64[ns]', length=265, freq=None)

# %%
df.isnull().sum()
# Out:
# RegionID         0
# RegionName       0
# City             0
# State            0
# Metro         1043
#               ...
# 2017-12          0
# 2018-01          0
# 2018-02          0
# 2018-03          0
# 2018-04          0
# Length: 272, dtype: int64

# %%
df.dtypes
# Out:
# RegionID       int64
# RegionName     int64
# City          object
# State         object
# Metro         object
#                ...
# 2017-12        int64
# 2018-01        int64
# 2018-02        int64
# 2018-03        int64
# 2018-04        int64
# Length: 272, dtype: object

# %%
# Checking null values
columns_with_missing_values = df.columns[df.isnull().any()]

# Calculate and print the sum and percentage of missing values for each column
for column in columns_with_missing_values:
    missing_sum = df[column].isnull().sum()
    total_entries = len(df)
    missing_percentage = (missing_sum / total_entries) * 100
    print(f"Column '{column}' has {missing_sum} missing values, which is {missing_percentage:.2f}% of total entries.")
# Out:
# Column 'Metro' has 1043 missing values, which is 7.08% of total entries.
# Column '1996-04' has 1039 missing values, which is 7.06% of total entries.
# Column '1996-05' has 1039 missing values, which is 7.06% of total entries.
# Column '1996-06' has 1039 missing values, which is 7.06% of total entries.
# Column '1996-07' has 1039 missing values, which is 7.06% of total entries.
# Column '1996-08' has 1039 missing values, which is 7.06% of total entries.
# Column '1996-09' has 1039 missing values, which is 7.06% of total entries.
# Column '1996-10' has 1039 missing values, which is 7.06% of total entries.
# Column '1996-11' has 1039 missing values, which is 7.06% of total entries.
# Column '1996-12' has 1039 missing values, which is 7.06% of total entries.
# Column '1997-01' has 1039 missing values, which is 7.06% of total entries.
# Column '1997-02' has 1039 missing values, which is 7.06% of total entries.
# Column '1997-03' has 1039 missing values, which is 7.06% of total entries.
# Column '1997-04' has 1039 missing values, which is 7.06% of total entries.
# Column '1997-05' has 1039 missing values, which is 7.06% of total entries.
# Column '1997-06' has 1039 missing values, which is 7.06% of total entries.
# Column '1997-07' has 1038 missing values, which is 7.05% of total entries.
# Column '1997-08' has 1038 missing values, which is 7.05% of total entries.
# Column '1997-09' has 1038 missing values, which is 7.05% of total entries.
# Column '1997-10' has 1038 missing values, which is 7.05% of total entries.
# Column '1997-11' has 1038 missing values, which is 7.05% of total entries.
# Column '1997-12' has 1038 missing values, which is 7.05% of total entries.
# Column '1998-01' has 1036 missing values, which is 7.04% of total entries.
# Column '1998-02' has 1036 missing values, which is 7.04% of total entries.
# Column '1998-03' has 1036 missing values, which is 7.04% of total entries.
# Column '1998-04' has 1036 missing values, which is 7.04% of total entries.
# Column '1998-05' has 1036 missing values, which is 7.04% of total entries.
# Column '1998-06' has 1036 missing values, which is 7.04% of total entries.
# Column '1998-07' has 1036 missing values, which is 7.04% of total entries.
# Column '1998-08' has 1036 missing values, which is 7.04% of total entries.
# Column '1998-09' has 1036 missing values, which is 7.04% of total entries.
# Column '1998-10' has 1036 missing values, which is 7.04% of total entries.
# Column '1998-11' has 1036 missing values, which is 7.04% of total entries.
# Column '1998-12' has 1036 missing values, which is 7.04% of total entries.
# Column '1999-01' has 1036 missing values, which is 7.04% of total entries.
# Column '1999-02' has 1036 missing values, which is 7.04% of total entries.
# Column '1999-03' has 1036 missing values, which is 7.04% of total entries.
# Column '1999-04' has 1036 missing values, which is 7.04% of total entries.
# Column '1999-05' has 1036 missing values, which is 7.04% of total entries.
# Column '1999-06' has 1036 missing values, which is 7.04% of total entries.
# Column '1999-07' has 1036 missing values, which is 7.04% of total entries.
# Column '1999-08' has 1036 missing values, which is 7.04% of total entries.
# Column '1999-09' has 1036 missing values, which is 7.04% of total entries.
# Column '1999-10' has 1036 missing values, which is 7.04% of total entries.
# Column '1999-11' has 1036 missing values, which is 7.04% of total entries.
# Column '1999-12' has 1036 missing values, which is 7.04% of total entries.
# Column '2000-01' has 1036 missing values, which is 7.04% of total entries.
# Column '2000-02' has 1036 missing values, which is 7.04% of total entries.
# Column '2000-03' has 1036 missing values, which is 7.04% of total entries.
# Column '2000-04' has 1036 missing values, which is 7.04% of total entries.
# Column '2000-05' has 1036 missing values, which is 7.04% of total entries.
# Column '2000-06' has 1036 missing values, which is 7.04% of total entries.
# Column '2000-07' has 1036 missing values, which is 7.04% of total entries.
# Column '2000-08' has 1036 missing values, which is 7.04% of total entries.
# Column '2000-09' has 1036 missing values, which is 7.04% of total entries.
# Column '2000-10' has 1036 missing values, which is 7.04% of total entries.
# Column '2000-11' has 1036 missing values, which is 7.04% of total entries.
# Column '2000-12' has 1036 missing values, which is 7.04% of total entries.
# Column '2001-01' has 1036 missing values, which is 7.04% of total entries.
# Column '2001-02' has 1036 missing values, which is 7.04% of total entries.
# Column '2001-03' has 1036 missing values, which is 7.04% of total entries.
# Column '2001-04' has 1036 missing values, which is 7.04% of total entries.
# Column '2001-05' has 1036 missing values, which is 7.04% of total entries.
# Column '2001-06' has 1036 missing values, which is 7.04% of total entries.
# Column '2001-07' has 1036 missing values, which is 7.04% of total entries.
# Column '2001-08' has 1036 missing values, which is 7.04% of total entries.
# Column '2001-09' has 1036 missing values, which is 7.04% of total entries.
# Column '2001-10' has 1036 missing values, which is 7.04% of total entries.
# Column '2001-11' has 1036 missing values, which is 7.04% of total entries.
# Column '2001-12' has 1036 missing values, which is 7.04% of total entries.
# Column '2002-01' has 1036 missing values, which is 7.04% of total entries.
# Column '2002-02' has 1036 missing values, which is 7.04% of total entries.
# Column '2002-03' has 1036 missing values, which is 7.04% of total entries.
# Column '2002-04' has 1036 missing values, which is 7.04% of total entries.
# Column '2002-05' has 1036 missing values, which is 7.04% of total entries.
# Column '2002-06' has 1036 missing values, which is 7.04% of total entries.
# Column '2002-07' has 1036 missing values, which is 7.04% of total entries.
# Column '2002-08' has 1036 missing values, which is 7.04% of total entries.
# Column '2002-09' has 1036 missing values, which is 7.04% of total entries.
# Column '2002-10' has 1036 missing values, which is 7.04% of total entries.
# Column '2002-11' has 1036 missing values, which is 7.04% of total entries.
# Column '2002-12' has 1036 missing values, which is 7.04% of total entries.
# Column '2003-01' has 1036 missing values, which is 7.04% of total entries.
# Column '2003-02' has 1036 missing values, which is 7.04% of total entries.
# Column '2003-03' has 1036 missing values, which is 7.04% of total entries.
# Column '2003-04' has 1036 missing values, which is 7.04% of total entries.
# Column '2003-05' has 1036 missing values, which is 7.04% of total entries.
# Column '2003-06' has 1036 missing values, which is 7.04% of total entries.
# Column '2003-07' has 918 missing values, which is 6.24% of total entries.
# Column '2003-08' has 918 missing values, which is 6.24% of total entries.
# Column '2003-09' has 918 missing values, which is 6.24% of total entries.
# Column '2003-10' has 918 missing values, which is 6.24% of total entries.
# Column '2003-11' has 918 missing values, which is 6.24% of total entries.
# Column '2003-12' has 918 missing values, which is 6.24% of total entries.
# Column '2004-01' has 887 missing values, which is 6.02% of total entries.
# Column '2004-02' has 887 missing values, which is 6.02% of total entries.
# Column '2004-03' has 887 missing values, which is 6.02% of total entries.
# Column '2004-04' has 887 missing values, which is 6.02% of total entries.
# Column '2004-05' has 887 missing values, which is 6.02% of total entries.
# Column '2004-06' has 887 missing values, which is 6.02% of total entries.
# Column '2004-07' has 866 missing values, which is 5.88% of total entries.
# Column '2004-08' has 866 missing values, which is 5.88% of total entries.
# Column '2004-09' has 866 missing values, which is 5.88% of total entries.
# Column '2004-10' has 866 missing values, which is 5.88% of total entries.
# Column '2004-11' has 866 missing values, which is 5.88% of total entries.
# Column '2004-12' has 866 missing values, which is 5.88% of total entries.
# Column '2005-01' has 814 missing values, which is 5.53% of total entries.
# Column '2005-02' has 814 missing values, which is 5.53% of total entries.
# Column '2005-03' has 801 missing values, which is 5.44% of total entries.
# Column '2005-04' has 801 missing values, which is 5.44% of total entries.
# Column '2005-05' has 801 missing values, which is 5.44% of total entries.
# Column '2005-06' has 801 missing values, which is 5.44% of total entries.
# Column '2005-07' has 723 missing values, which is 4.91% of total entries.
# Column '2005-08' has 723 missing values, which is 4.91% of total entries.
# Column '2005-09' has 723 missing values, which is 4.91% of total entries.
# Column '2005-10' has 723 missing values, which is 4.91% of total entries.
# Column '2005-11' has 723 missing values, which is 4.91% of total entries.
# Column '2005-12' has 723 missing values, which is 4.91% of total entries.
# Column '2006-01' has 667 missing values, which is 4.53% of total entries.
# Column '2006-02' has 667 missing values, which is 4.53% of total entries.
# Column '2006-03' has 667 missing values, which is 4.53% of total entries.
# Column '2006-04' has 667 missing values, which is 4.53% of total entries.
# Column '2006-05' has 667 missing values, which is 4.53% of total entries.
# Column '2006-06' has 667 missing values, which is 4.53% of total entries.
# Column '2006-07' has 640 missing values, which is 4.35% of total entries.
# Column '2006-08' has 640 missing values, which is 4.35% of total entries.
# Column '2006-09' has 640 missing values, which is 4.35% of total entries.
# Column '2006-10' has 640 missing values, which is 4.35% of total entries.
# Column '2006-11' has 640 missing values, which is 4.35% of total entries.
# Column '2006-12' has 640 missing values, which is 4.35% of total entries.
# Column '2007-01' has 620 missing values, which is 4.21% of total entries.
# Column '2007-02' has 620 missing values, which is 4.21% of total entries.
# Column '2007-03' has 620 missing values, which is 4.21% of total entries.
# Column '2007-04' has 620 missing values, which is 4.21% of total entries.
# Column '2007-05' has 620 missing values, which is 4.21% of total entries.
# Column '2007-06' has 620 missing values, which is 4.21% of total entries.
# Column '2007-07' has 613 missing values, which is 4.16% of total entries.
# Column '2007-08' has 613 missing values, which is 4.16% of total entries.
# Column '2007-09' has 613 missing values, which is 4.16% of total entries.
# Column '2007-10' has 613 missing values, which is 4.16% of total entries.
# Column '2007-11' has 613 missing values, which is 4.16% of total entries.
# Column '2007-12' has 613 missing values, which is 4.16% of total entries.
# Column '2008-01' has 607 missing values, which is 4.12% of total entries.
# Column '2008-02' has 607 missing values, which is 4.12% of total entries.
# Column '2008-03' has 607 missing values, which is 4.12% of total entries.
# Column '2008-04' has 607 missing values, which is 4.12% of total entries.
# Column '2008-05' has 607 missing values, which is 4.12% of total entries.
# Column '2008-06' has 607 missing values, which is 4.12% of total entries.
# Column '2008-07' has 598 missing values, which is 4.06% of total entries.
# Column '2008-08' has 598 missing values, which is 4.06% of total entries.
# Column '2008-09' has 598 missing values, which is 4.06% of total entries.
# Column '2008-10' has 598 missing values, which is 4.06% of total entries.
# Column '2008-11' has 598 missing values, which is 4.06% of total entries.
# Column '2008-12' has 598 missing values, which is 4.06% of total entries.
# Column '2009-01' has 587 missing values, which is 3.99% of total entries.
# Column '2009-02' has 587 missing values, which is 3.99% of total entries.
# Column '2009-03' has 587 missing values, which is 3.99% of total entries.
# Column '2009-04' has 587 missing values, which is 3.99% of total entries.
# Column '2009-05' has 587 missing values, which is 3.99% of total entries.
# Column '2009-06' has 587 missing values, which is 3.99% of total entries.
# Column '2009-07' has 580 missing values, which is 3.94% of total entries.
# Column '2009-08' has 580 missing values, which is 3.94% of total entries.
# Column '2009-09' has 580 missing values, which is 3.94% of total entries.
# Column '2009-10' has 580 missing values, which is 3.94% of total entries.
# Column '2009-11' has 580 missing values, which is 3.94% of total entries.
# Column '2009-12' has 580 missing values, which is 3.94% of total entries.
# Column '2010-01' has 579 missing values, which is 3.93% of total entries.
# Column '2010-02' has 579 missing values, which is 3.93% of total entries.
# Column '2010-03' has 349 missing values, which is 2.37% of total entries.
# Column '2010-04' has 349 missing values, which is 2.37% of total entries.
# Column '2010-05' has 349 missing values, which is 2.37% of total entries.
# Column '2010-06' has 349 missing values, which is 2.37% of total entries.
# Column '2010-07' has 308 missing values, which is 2.09% of total entries.
# Column '2010-08' has 308 missing values, which is 2.09% of total entries.
# Column '2010-09' has 308 missing values, which is 2.09% of total entries.
# Column '2010-10' has 308 missing values, which is 2.09% of total entries.
# Column '2010-11' has 308 missing values, which is 2.09% of total entries.
# Column '2010-12' has 308 missing values, which is 2.09% of total entries.
# Column '2011-01' has 275 missing values, which is 1.87% of total entries.
# Column '2011-02' has 275 missing values, which is 1.87% of total entries.
# Column '2011-03' has 275 missing values, which is 1.87% of total entries.
# Column '2011-04' has 275 missing values, which is 1.87% of total entries.
# Column '2011-05' has 275 missing values, which is 1.87% of total entries.
# Column '2011-06' has 275 missing values, which is 1.87% of total entries.
# Column '2011-07' has 251 missing values, which is 1.70% of total entries.
# Column '2011-08' has 251 missing values, which is 1.70% of total entries.
# Column '2011-09' has 251 missing values, which is 1.70% of total entries.
# Column '2011-10' has 251 missing values, which is 1.70% of total entries.
# Column '2011-11' has 251 missing values, which is 1.70% of total entries.
# Column '2011-12' has 251 missing values, which is 1.70% of total entries.
# Column '2012-01' has 224 missing values, which is 1.52% of total entries.
# Column '2012-02' has 224 missing values, which is 1.52% of total entries.
# Column '2012-03' has 224 missing values, which is 1.52% of total entries.
# Column '2012-04' has 224 missing values, which is 1.52% of total entries.
# Column '2012-05' has 224 missing values, which is 1.52% of total entries.
# Column '2012-06' has 224 missing values, which is 1.52% of total entries.
# Column '2012-07' has 206 missing values, which is 1.40% of total entries.
# Column '2012-08' has 206 missing values, which is 1.40% of total entries.
# Column '2012-09' has 206 missing values, which is 1.40% of total entries.
# Column '2012-10' has 206 missing values, which is 1.40% of total entries.
# Column '2012-11' has 206 missing values, which is 1.40% of total entries.
# Column '2012-12' has 206 missing values, which is 1.40% of total entries.
# Column '2013-01' has 151 missing values, which is 1.03% of total entries.
# Column '2013-02' has 151 missing values, which is 1.03% of total entries.
# Column '2013-03' has 151 missing values, which is 1.03% of total entries.
# Column '2013-04' has 151 missing values, which is 1.03% of total entries.
# Column '2013-05' has 151 missing values, which is 1.03% of total entries.
# Column '2013-06' has 151 missing values, which is 1.03% of total entries.
# Column '2013-07' has 109 missing values, which is 0.74% of total entries.
# Column '2013-08' has 109 missing values, which is 0.74% of total entries.
# Column '2013-09' has 109 missing values, which is 0.74% of total entries.
# Column '2013-10' has 109 missing values, which is 0.74% of total entries.
# Column '2013-11' has 109 missing values, which is 0.74% of total entries.
# Column '2013-12' has 109 missing values, which is 0.74% of total entries.
# Column '2014-01' has 56 missing values, which is 0.38% of total entries.
# Column '2014-02' has 56 missing values, which is 0.38% of total entries.
# Column '2014-03' has 56 missing values, which is 0.38% of total entries.
# Column '2014-04' has 56 missing values, which is 0.38% of total entries.
# Column '2014-05' has 56 missing values, which is 0.38% of total entries.
# Column '2014-06' has 56 missing values, which is 0.38% of total entries.

# %% [markdown]
# Dropping missing values as they are of lower percentage

# %%
#dropping missing values
df1 = df.dropna()

# %%
#checking shape of the df after dropping missing values
df1.shape
# Out:
# (12895, 272)

# %%
# checking for duplicates
df1.duplicated().value_counts()
# Out:
# False    12895
# dtype: int64

# %%
get_datetimes(df)
# Out:
# DatetimeIndex(['1996-04-01', '1996-05-01', '1996-06-01', '1996-07-01',
#                '1996-08-01', '1996-09-01', '1996-10-01', '1996-11-01',
#                '1996-12-01', '1997-01-01',
#                ...
#                '2017-07-01', '2017-08-01', '2017-09-01', '2017-10-01',
#                '2017-11-01', '2017-12-01', '2018-01-01', '2018-02-01',
#                '2018-03-01', '2018-04-01'],
#               dtype='datetime64[ns]', length=265, freq=None)

# %%
df.values
# Out:
# array([[84654, 60657, 'Chicago', ..., 1030700, 1033800, 1030600],
#        [90668, 75070, 'McKinney', ..., 319600, 321100, 321800],
#        [91982, 77494, 'Katy', ..., 323000, 326900, 329900],
#        ...,
#        [75672, 40404, 'Berea', ..., 132500, 133000, 133400],
#        [93733, 81225, 'Mount Crested Butte', ..., 705300, 681500, 664400],
#        [95851, 89155, 'Mesquite', ..., 353000, 356000, 357200]],
#       dtype=object)

# %%
def melt_data(df):
    """
    Takes the zillow_data dataset in wide form or a subset of the zillow_dataset.  
    Returns a long-form datetime dataframe 
    with the datetime column names as the index and the values as the 'values' column.
    
    If more than one row is passes in the wide-form dataset, the values column
    will be the mean of the values from the datetime columns in all of the rows.
    """
    
    melted = pd.melt(df, id_vars=['RegionName', 'RegionID', 'SizeRank', 'City', 'State', 'Metro', 'CountyName'], var_name='time')
    melted['time'] = pd.to_datetime(melted['time'], infer_datetime_format=True)
    melted = melted.dropna(subset=['value'])
    return melted.groupby('time').aggregate({'value':'mean'})

# %%
melt_data(df)
# Out:
#                     value
# time
# 1996-04-01  118299.123063
# 1996-05-01  118419.044139
# 1996-06-01  118537.423268
# 1996-07-01  118653.069278
# 1996-08-01  118780.254312
# ...                   ...
# 2017-12-01  281095.320247
# 2018-01-01  282657.060382
# 2018-02-01  284368.688447
# 2018-03-01  286511.376757
# 2018-04-01  288039.944305
#
# [265 rows x 1 columns]
